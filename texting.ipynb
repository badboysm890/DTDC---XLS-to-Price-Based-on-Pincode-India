# %%
import pandas as pd


# load csv file pincode.csv
# where all the columns are whole numbers

df = pd.read_csv('pincode.csv')
df = df.fillna(0)
df = df.astype(int)


tamilnadu = df['tamilnadu'].tolist()
south = df['south'].tolist()
north = df['north'].tolist()


df1 = pd.read_csv('data.csv')
df1['weight'] = df1['weight'].astype(float)
df1['pincode'] = df1['pincode'].astype(int)
df1['mode'] = df1['mode'].astype(str)

# create a new column in df1 called 'price'

# create a df called df2 with col pincode, weight, mode, price
df2 = pd.DataFrame(columns=['pincode', 'weight', 'mode', 'price'])


for index, row in df1.iterrows():

    pincode = row['pincode']
    weight = row['weight']
    mode = row['mode']

    # print(pincode, weight, mode)
    print(mode)
    if pincode == 533432:
        print(pincode, weight, mode)
        exit()
    if pincode in tamilnadu:
        print('tamilnadu')

        if weight < 1:
            print("weight 0-1", weight)
            print(30)
            # append to df2
            df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
        # elif  weight between 1-5  then 0.5 kg is 15rs
        elif weight  > 1 and weight <= 5:
            howMany = int(weight / 0.5)
            leftOver = weight % 0.5
            leftOver = weight - (howMany * 0.5)
            if leftOver > 0:
                howMany = howMany + 1
            print("weight between 1-5", weight)
            print(howMany * 15)
            df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
         # weight between 5-10 then 0.5 kg is  11 rs
        elif weight  > 5 and weight <= 10:
            howMany = int(weight / 0.5)
            leftOver = weight % 0.5
            leftOver = weight - (howMany * 0.5)
            if leftOver > 0:
                howMany = howMany + 1
            print("weight between 5-10", weight)
            print(howMany * 11)
            row['price'] = howMany * 11
            df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 11}, ignore_index=True)
        # weight between 10-15 then 0.5 kg is  9 rs
        elif weight  > 10 and weight <= 15:
            howMany = int(weight / 0.5)
            leftOver = weight % 0.5
            leftOver = weight - (howMany * 0.5)
            if leftOver > 0:
                howMany = howMany + 1
            print("weight between 15-20", weight)
            print(howMany * 9)  
            row['price'] = howMany *9  
            df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 9}, ignore_index=True)
        # weight between 15-20 then 0.5 kg is  7.5 rs
        elif weight  > 15 and weight <= 20:
            howMany = int(weight / 0.5)
            leftOver = weight % 0.5
            leftOver = weight - (howMany * 0.5)
            if leftOver > 0:
                howMany = howMany + 1
            print("weight between 15-20", weight)
            print(howMany * 7.5)
            row['price'] = howMany * 7.5
            df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 7.5}, ignore_index=True)

        # weight between 20-100 then 0.5 kg is  7 rs
        elif weight  > 20 and weight <= 100:
            howMany = int(weight / 0.5)
            leftOver = weight % 0.5
            leftOver = weight - (howMany * 0.5)
            if leftOver > 0:
                howMany = howMany + 1
            print("weight between 20-100", weight)
            print(howMany * 7)   
            row['price'] = howMany * 7 
            df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 7}, ignore_index=True)
        else:
            df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)    
    elif pincode in south:
         print('south')
         if weight < 1:
             print("weight between 0-1", weight)
             print(40)
             row['price'] = 40
         elif weight  > 1 and weight <= 5:
             howMany = int(weight / 0.5)
             leftOver = weight % 0.5
             leftOver = weight - (howMany * 0.5)
             if leftOver > 0:
                 howMany = howMany + 1
             print("weight between 1-5", weight)
             print(howMany * 20)
             df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
        # weight between 5-10 then 0.5 kg is  17.5 rs
         elif weight  > 5 and weight <= 10:
             howMany = int(weight / 0.5)
             leftOver = weight % 0.5
             leftOver = weight - (howMany * 0.5)
             if leftOver > 0:
                 howMany = howMany + 1
             print("weight between 5-10", weight)
             print(howMany * 17.5)
             df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 17.5}, ignore_index=True)
         # weight between 10-15 then 0.5 kg is  15 rs
         elif weight  > 10 and weight <= 15:
             howMany = int(weight / 0.5)
             leftOver = weight % 0.5
             leftOver = weight - (howMany * 0.5)
             if leftOver > 0:
                 howMany = howMany + 1
             print("weight between 10-15", weight)
             print(howMany * 15)
             df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
         elif weight  > 15 and weight <= 20:
             howMany = int(weight / 0.5)
             leftOver = weight % 0.5
             leftOver = weight - (howMany * 0.5)
             if leftOver > 0:
                 howMany = howMany + 1
             print("weight between 15-20", weight)
             print(howMany * 13.5)
             df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 13.5}, ignore_index=True)
         elif weight  > 20 and weight <= 100:
             howMany = int(weight / 0.5)
             leftOver = weight % 0.5
             leftOver = weight - (howMany * 0.5)
             if leftOver > 0:
                 howMany = howMany + 1
             print("weight between 1-5", weight)
             print(howMany * 12.5)
             df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 12.5}, ignore_index=True)

    elif pincode in north:
        print('north')
        
        if mode == 'AR' or mode == 'AC':
            print('AR')
            if weight < 1:
                print("weight > 1", weight)
                print(120)
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
            elif weight > 1 and weight <= 5:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 1-5", weight)
                print(howMany * 60)
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 60}, ignore_index=True)
            elif weight > 5 and weight <= 10:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 5-10", weight)
                print(howMany * 57.5)
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 57.5}, ignore_index=True)
            elif weight > 10 and weight <= 25:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 10-25", weight)
                print(howMany * 55)    
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 55}, ignore_index=True)
            elif  weight > 25 and weight <= 100:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 25-100", weight)
                print(howMany * 52.5)   
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 52.5}, ignore_index=True)
        elif mode == "SF":
            print("SF ------------>")
            if weight < 1:
                print("weight > 1", weight)
                print(240)
                row['price'] = 240
            elif weight > 2.5 and weight <= 5:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 1-5", weight)
                print(howMany * 40)
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 40}, ignore_index=True)
            elif weight > 5 and weight <= 10:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 5-10", weight)
                print(howMany * 30)
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 30}, ignore_index=True)
            elif weight > 10 and weight <= 15:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 10-15", weight)
                print(howMany * 27.5)    
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 27.5}, ignore_index=True)
            elif  weight > 15 and weight <= 20:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 25-100", weight)
                print(howMany * 25)  
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 25}, ignore_index=True)
            elif  weight > 20 and weight <= 25:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 20-25", weight)
                print(howMany * 22.5)
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 22.5}, ignore_index=True)
            elif weight > 25 and weight <= 100:
                howMany = int(weight / 0.5)
                leftOver = weight % 0.5
                leftOver = weight - (howMany * 0.5)
                if leftOver > 0:
                    howMany = howMany + 1
                print("weight between 25-100", weight)
                print(howMany * 20)   
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
            else:
                print("SFFFF found------------>", pincode, mode, weight)    
                df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)
        else:
                    print("SFFFF found------------>", pincode, mode, weight)  
                    df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)    
    else:
        print("not found------------>", pincode, mode, weight)
        df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)
# Out:
# AR
# tamilnadu
# weight between 1-5 1.02
# 45
# SF
# SF <--------------->
# 636005 0.5 SF
# tamilnadu
# weight 0-1 0.5
# 30
# AR
# south
# weight between 0-1 0.21
# 40
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# tamilnadu
# weight 0-1 0.59
# 30
# AR
# south
# weight between 0-1 0.964
# 40
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# north
# AR
# weight > 1 0.729
# 120
# AR
# south
# weight between 0-1 0.7
# 40
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# north
# AR
# weight > 1 0.603
# 120
# AR
# south
# weight between 0-1 0.65
# 40
# AR
# tamilnadu
# weight 0-1 0.6
# 30
# AR
# north
# AR
# weight between 1-5 4.447
# 540
# AR
# south
# weight between 0-1 0.663
# 40
# AR
# tamilnadu
# weight between 1-5 1.2
# 45
# AR
# south
# weight between 1-5 3.187
# 140
# AR
# tamilnadu
# weight between 1-5 1.92
# 60
# AR
# north
# AR
# weight > 1 0.602
# 120
# AR
# south
# weight between 0-1 0.743
# 40
# AR
# south
# weight between 0-1 0.73
# 40
# AR
# south
# weight between 0-1 0.84
# 40
# AR
# south
# weight between 1-5 1.15
# 60
# AR
# north
# AR
# weight > 1 0.837
# 120
# AR
# north
# AR
# weight > 1 0.644
# 120
# AR
# north
# AR
# weight > 1 0.715
# 120
# AR
# south
# weight between 0-1 0.927
# 40
# AR
# north
# AR
# weight > 1 0.609
# 120
# AR
# not found------------> 442310 AR 0.665
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# south
# weight between 0-1 0.5
# 40
# AR
# north
# AR
# weight between 1-5 1.906
# 240
# AR
# south
# weight between 1-5 4.3
# 180
# AR
# tamilnadu
# weight 0-1 0.8
# 30
# AR
# tamilnadu
# weight 0-1 0.75
# 30
# AR
# north
# AR
# weight > 1 0.853
# 120
# AR
# south
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# south
# weight between 0-1 0.5
# 40
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# north
# AR
# weight between 1-5 1.736
# 240
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# tamilnadu
# weight between 1-5 1.2
# 45
# AR
# north
# AR
# weight between 1-5 2.214
# 300
# AR
# south
# weight between 1-5 1.051
# 60
# AR
# north
# AR
# weight > 1 0.542
# 120
# AR
# south
# weight between 0-1 0.715
# 40
# AR
# south
# weight between 1-5 2.4
# 100
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# south
# weight between 1-5 1.288
# 60
# AR
# tamilnadu
# weight between 1-5 2.05
# 75
# AR
# tamilnadu
# weight between 1-5 3.4
# 105
# AR
# south
# weight between 0-1 0.52
# 40
# AR
# south
# weight between 0-1 0.75
# 40
# AR
# north
# AR
# weight between 1-5 1.088
# 180
# AR
# tamilnadu
# weight 0-1 0.5
# 30
# AR
# south
# weight between 1-5 1.95
# 80
# AR
# tamilnadu
# weight between 1-5 1.85
# 60
# AR
# south
# weight between 0-1 0.65
# 40
# AR
# south
# weight between 0-1 0.619
# 40
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# south
# weight between 0-1 0.95
# 40
# AR
# south
# weight between 0-1 0.39
# 40
# AR
# south
# weight between 0-1 0.76
# 40
# AR
# south
# weight between 0-1 0.509
# 40
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# south
# weight between 0-1 0.739
# 40
# AR
# tamilnadu
# weight 0-1 0.8
# 30
# AR
# south
# weight between 0-1 0.54
# 40
# AR
# south
# weight between 0-1 0.782
# 40
# AR
# south
# weight between 0-1 0.991
# 40
# AR
# north
# AR
# weight between 1-5 1.699
# 240
# AR
# tamilnadu
# weight 0-1 0.57
# 30
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# south
# weight between 1-5 1.968
# 80
# AR
# tamilnadu
# weight between 1-5 1.15
# 45
# AR
# south
# weight between 0-1 0.546
# 40
# AR
# tamilnadu
# weight 0-1 0.6
# 30
# AR
# south
# weight between 0-1 0.57
# 40
# AR
# tamilnadu
# weight 0-1 0.56
# 30
# AR
# south
# weight between 1-5 1.17
# 60
# AR
# south
# weight between 0-1 0.45
# 40
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# tamilnadu
# weight 0-1 0.5
# 30
# AR
# tamilnadu
# weight 0-1 0.65
# 30
# AR
# tamilnadu
# weight 0-1 0.258
# 30
# AR
# tamilnadu
# weight 0-1 0.65
# 30
# AR
# tamilnadu
# weight 0-1 0.65
# 30
# AR
# tamilnadu
# weight 0-1 0.65
# 30
# AR
# tamilnadu
# weight 0-1 0.95
# 30
# AR
# south
# weight between 0-1 0.5
# 40
# AR
# south
# weight between 1-5 1.02
# 60
# AR
# south
# weight between 1-5 1.359
# 60
# AR
# south
# weight between 0-1 0.5
# 40
# AR
# south
# weight between 1-5 1.02
# 60
# AR
# north
# AR
# weight > 1 0.606
# 120
# AR
# south
# weight between 1-5 2.6
# 120
# AR
# not found------------> 110018 AR 0.763
# AR
# south
# weight between 0-1 0.8
# 40
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# tamilnadu
# weight 0-1 0.69
# 30
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# south
# weight between 1-5 2.363
# 100
# AR
# tamilnadu
# weight 0-1 0.61
# 30
# AR
# tamilnadu
# weight 0-1 0.75
# 30
# AR
# tamilnadu
# weight 0-1 0.51
# 30
# AR
# south
# weight between 0-1 0.939
# 40
# AR
# south
# weight between 0-1 0.588
# 40
# AR
# tamilnadu
# weight 0-1 0.89
# 30
# AR
# tamilnadu
# weight 0-1 0.58
# 30
# AR
# south
# weight between 0-1 0.82
# 40
# AR
# south
# weight between 1-5 1.2
# 60
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# north
# AR
# weight > 1 0.616
# 120
# AR
# north
# AR
# weight between 1-5 1.099
# 180
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# south
# weight between 1-5 1.73
# 80
# AR
# south
# weight between 0-1 0.621
# 40
# AR
# north
# AR
# weight > 1 0.823
# 120
# AR
# north
# AR
# weight > 1 0.706
# 120
# AR
# south
# weight between 0-1 0.737
# 40
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# south
# weight between 1-5 1.77
# 80
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# south
# weight between 0-1 0.709
# 40
# AR
# south
# weight between 1-5 2.102
# 100
# AR
# not found------------> 502230 AR 2.8
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# south
# AR
# tamilnadu
# weight 0-1 0.45
# 30
# AR
# north
# AR
# weight > 1 0.627
# 120
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# south
# weight between 0-1 0.555
# 40
# AR
# tamilnadu
# weight 0-1 0.8
# 30
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# south
# weight between 0-1 0.85
# 40
# AR
# south
# weight between 1-5 1.8
# 80
# AR
# tamilnadu
# weight between 1-5 1.29
# 45
# AR
# tamilnadu
# weight between 1-5 1.27
# 45
# AR
# south
# weight between 0-1 0.862
# 40
# AR
# south
# weight between 0-1 0.85
# 40
# AR
# tamilnadu
# weight between 1-5 2.55
# 90
# AR
# south
# weight between 1-5 1.16
# 60
# AR
# south
# weight between 1-5 1.049
# 60
# AR
# south
# weight between 0-1 0.703
# 40
# AR
# south
# weight between 0-1 0.747
# 40
# AR
# north
# AR
# weight > 1 0.721
# 120
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# south
# weight between 1-5 1.15
# 60
# AR
# south
# weight between 0-1 0.95
# 40
# AR
# tamilnadu
# weight between 1-5 1.55
# 60
# AR
# tamilnadu
# weight 0-1 0.6
# 30
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# tamilnadu
# weight 0-1 0.62
# 30
# AR
# tamilnadu
# weight 0-1 0.55
# 30
# AR
# tamilnadu
# weight 0-1 0.56
# 30
# AR
# tamilnadu
# weight 0-1 0.75
# 30
# AR
# tamilnadu
# weight between 1-5 1.28
# 45
# AR
# tamilnadu
# weight 0-1 0.65
# 30
# AR
# tamilnadu
# weight 0-1 0.6
# 30
# AR
# north
# AR
# weight > 1 0.644
# 120
# AR
# not found------------> 620052 AR 0.75
# AR
# tamilnadu
# weight between 1-5 1.71
# 60
# AR
# south
# weight between 0-1 0.95
# 40
# AR
# north
# AR
# weight > 1 0.643
# 120
# AR
# south
# weight between 0-1 0.85
# 40
# AR
# south
# weight between 0-1 0.77
# 40
# AR
# south
# weight between 0-1 0.86
# 40
# AR
# south
# weight between 0-1 0.983
# 40
# AR
# tamilnadu
# weight 0-1 0.98
# 30
# AR
# south
# weight between 0-1 0.78
# 40
# AR
# south
# weight between 1-5 1.65
# 80
# AR
# south
# weight between 1-5 3.0
# 120
# AR
# north
# AR
# weight > 1 0.737
# 120
# AR
# south
# weight between 0-1 0.9
# 40
# AR
# tamilnadu
# weight 0-1 0.5
# 30
# AR
# tamilnadu
# weight 0-1 0.65
# 30
# AR
# south
# weight between 0-1 0.619
# 40
# AR
# south
# weight between 1-5 1.384
# 60
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# south
# weight between 0-1 0.656
# 40
# AR
# tamilnadu
# weight between 1-5 1.02
# 45
# AR
# south
# weight between 0-1 0.72
# 40
# AR
# south
# weight between 0-1 0.55
# 40
# AR
# north
# AR
# weight between 1-5 3.219
# 420
# AR
# tamilnadu
# weight 0-1 0.56
# 30
# AR
# south
# weight between 0-1 0.562
# 40
# AR
# tamilnadu
# weight 0-1 0.5
# 30
# AR
# south
# weight between 0-1 0.65
# 40
# AR
# north
# AR
# weight > 1 0.731
# 120
# AR
# north
# AR
# weight > 1 0.582
# 120
# AR
# south
# weight between 0-1 0.6
# 40
# AR
# south
# weight between 1-5 1.55
# 80
# AR
# south
# weight between 0-1 0.69
# 40
# AR
# south
# weight between 0-1 0.65
# 40
# AR
# south
# weight between 1-5 2.739
# 120
# AR
# south
# weight between 1-5 1.16
# 60
# AR
# south
# weight between 0-1 0.563
# 40
# AR
# tamilnadu
# weight between 1-5 1.17
# 45
# SF
# SF <--------------->
# 395010 3.112 SF
# north
# SF ------------>
# weight between 1-5 3.112
# 280
# SF
# SF <--------------->
# 500035 6.152 SF
# south
# weight between 5-10 6.152
# 227.5
# SF
# SF <--------------->
# 518222 16.9 SF
# south
# weight between 15-20 16.9
# 459.0
# SF
# SF <--------------->
# 587116 5.976 SF
# south
# weight between 5-10 5.976
# 210.0
# SF
# SF <--------------->
# 600001 24.0 SF
# tamilnadu
# weight between 20-100 24.0
# 336
# SF
# SF <--------------->
# 602105 6.2 SF
# tamilnadu
# weight between 5-10 6.2
# 143
# SF
# SF <--------------->
# 670582 4.4 SF
# south
# weight between 1-5 4.4
# 180
# AC
# north
# AR
# weight between 5-10 7.038
# 862.5
# SF
# SF <--------------->
# 560064 7.4 SF
# south
# weight between 5-10 7.4
# 262.5
# SF
# SF <--------------->
# 560064 6.8 SF
# south
# weight between 5-10 6.8
# 245.0
# SF
# SF <--------------->
# 575001 7.893 SF
# south
# weight between 5-10 7.893
# 280.0
# SF
# SF <--------------->
# 673012 16.6 SF
# south
# weight between 15-20 16.6
# 459.0
# SF
# SF <--------------->
# 626130 8.7 SF
# tamilnadu
# weight between 5-10 8.7
# 198
# SF
# SF <--------------->
# 600034 0.7 SF
# tamilnadu
# weight 0-1 0.7
# 30
# SF
# SF <--------------->
# 695002 1.34 SF
# south
# weight between 1-5 1.34
# 60
# SF
# SF <--------------->
# 560069 0.52 SF
# not found------------> 560069 SF 0.52
# SF
# SF <--------------->
# 641006 0.65 SF
# tamilnadu
# weight 0-1 0.65
# 30
# SF
# SF <--------------->
# 584111 0.6 SF
# south
# weight between 0-1 0.6
# 40
# SF
# SF <--------------->
# 560068 0.78 SF
# south
# weight between 0-1 0.78
# 40
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:175: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 60}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:271: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:175: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 60}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:175: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 60}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:175: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 60}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:175: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 60}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:175: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 60}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:271: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:175: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 60}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:271: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:157: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:271: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:175: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 60}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:166: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 120}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 15}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:217: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 40}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 17.5}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:146: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 13.5}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 17.5}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 7}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 11}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:184: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 57.5}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 17.5}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 17.5}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 17.5}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:146: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 13.5}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 11}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': howMany * 20}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:271: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 0}, ignore_index=True)
# /var/folders/xw/1z1qfr753ml6qzgm3ktssks00000gn/T/ipykernel_30910/2116925788.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'pincode': pincode, 'weight': weight, 'mode': mode, 'price': 30}, ignore_index=True)

# %%
# save the dataframe as a csv file

df2.to_csv('output.csv', index=False)
